# %% [markdown]
# # **Домашнее задание "Базовые навыки обработки данных в питоне"**
#
# Дата выдачи: 04.12.2025
#
# Дедлайн: 10.12.2025

# %% [markdown]
# Знаем, что у вас сейчас много домашки, поэтому даем несколько простеньких заданий, чтоб потренировать геокодинг, решейпинг и мерджинг. Дз не займет много времени, но практика будет достаточно полезной, как минимум последние два навыка вам точно пригодятся!
#
# Удачи!

# %% [markdown]
# # Задача 1, разогрев, 1.5 балла
# Напишите программу, которая принимает адрес от пользователя и возвращает его географические координаты (широту и долготу). Если адрес не найден, программа должна выводить сообщение об ошибке.

# %%
#your code here

# %% [markdown]
# # Задача 2. Работа с массивом, 3.5 балла
#
# Массивы можно извлекать как по ссылке, так и загружая файлом. Массив который нам необходимнаходится в открытом доступе. Найти массив можно здесь: https://hubofdata.ru/dataset/crime-rate/resource/3d3c7a68-b047-48d2-94c0-54d01b1abb39

# %% [markdown]
# **Задание 2.1 (1 балл)**
#
# Зайдите на сайт, найдите ссылку на массив. Импортируйте библиотеки: pandas, numpy, matplotlib.pyplot
#
# Создайте датафрейм из таблицы.
#
# Посморите, как выглядит датайфрейм, изучите его первые 10 строчек.
#
# Выведите описательные статистики по столбцам — количество значений, среднее, стандартное отклонение (корень из дисперсии), минимум, квантили, максимум.

# %%
#your_code_here

# %% [markdown]
# **Задание 2.2 (2 балла)**
#
# Постройте гистограмму, иллюстрирующую среднее количество каждого типа преступления за 2003 год.
#
# Постройте диаграму рассеяния между переменными Ecological и Murder. Есть ли корреляция между переменными?
#
# Сформулируйте разницу между гистограммой и диаграммой рассеяния. Какой тип данных используется, какова цель использования каждого графика?

# %%
#your_code_here

# %% [markdown]
# **Задание 2.3 (0,5 балла)**
# Сколько в выборке экологических преступлений? Какова их доля от общего числа преступлений?

# %% [markdown]
# **Задание 2.4 (2 балла)**
#
# Создайте таблицу, которая бы включала в себя только следующие столбики: Month, Total_crimes, Hooligan.
#
# Создайте столбик "Level_of_hooligan_crimes", в котором если количество преступлений выше среднего в этом столбике будет выводиться значение "High" а если меньше или равно будет выводиться значение "Low".
#
# Отсортируйте датафрейм по **убыванию** количества совершенных преступлений по статье "Хулиганство".
#
# Оставьте только первые 10 строчек.

# %%
#your_code_here

# %% [markdown]
# # Задача 3 Еще один массив (и еще один) (3 балла)
# Вместе с ноутбуком также прикреплены два массива, это преобразованные данные Росстата за 2022-2023 годы. Загрузите оба массива.

# %%
#your_code_here

# %% [markdown]
# **Задача 3.1 (1 балл)**
# В первом массиве информация о рождаемости и смертности, во втором - о браках и разводах. Объедините массивы.
#
# Обратите внимание что первый столбик назван криво (в нем заголовок, не отражающий сути столбика, это произошло из-за форматирования таблицы) - переименуйте столбец.

# %%
#your_code_here

# %% [markdown]
# **Задача 3.2 (2 балла)**
# Сделайте решейпинг массива в длинный формат с помощьюю метода melt для рождаемости.
# Остортируйте по первому столбцу и по годам.

# %%
#your_code_here

# %% [markdown]
# # Задача 4 - Курсовая работа (2 балла)
# Кратко опишите общий замысел вашей курсовой работы.
#
# **Для исследовательских проектов**: опишите исследовательский вопрос и общий замысел работы, попытайтесь сформулировать гипотезы с обоснованием.
#
# **Для прикладных проектов и стартапов**: опишите общий замысел продукта, какие функции и/или фичи он будет включать, кто будет им пользоваться, актуальность продуктовой идеи (может быть рыночной и/или социальной).

# %% [markdown]
# Ваш ответ здесь

# %% [markdown]
# # **Самое важное задание**
# Прикрепите картинку, которая описывает ваше состояние перед новогодней сессией, чтобы ассистам было веселее проверять :>>>>>>
